# %% [markdown]
# Creating Variables for Railway Information

# %%
train_name = "Rajdhani Express"
train_number = 12952
source_station = "New Delhi"
destination_station = "Mumbai Central"
ticket_price = 2450.75

# %% [markdown]
# Displaying Welcome Message and Train Details

# %%
print("Welcome to the  Indian Railway Reservation System")
print("Train Name:", train_name)
print("Train Number:", train_number)
print("Source Station:", source_station)
print("Destination Station:", destination_station)
# Out:
# Welcome to the  Indian Railway Reservation System
# Train Name: Rajdhani Express
# Train Number: 12952
# Source Station: New Delhi
# Destination Station: Mumbai Central

# %% [markdown]
# Data Types

# %%
print(type(train_name))
print(type(train_number))
print(type(ticket_price))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Identifiers and Literals

# %%
passenger_name = "Rahul Sharma"
seat_number = "B2-45"
is_confirmed = True

# %% [markdown]
# Type Casting

# %%
ticket_price_integer = int(ticket_price)
print(type(ticket_price_integer))
# Out:
# <class 'int'>

# %%
train_number_string = str(train_number)
print(type(train_number_string))
# Out:
# <class 'str'>

# %% [markdown]
# Implicit Typecasting

# %%
passenger_name = input("Enter your name:")
type(passenger_name)
# Out:
# str

# %% [markdown]
# Explicit Typecasting

# %%
ticket_price = int(input("Enter the ticket price:"))
print(type(ticket_price))
# Out:
# <class 'int'>

# %% [markdown]
# Comments in Python Program

# %%
# Railway Reservation Output System

#Passenger Information
passenger_name = "Rahul Sharma"

#Ticket Confirmation Status
confirmation_status = True

# %% [markdown]
# Ticket Confirmation Message

# %%
passenger_name = "Rahul Sharma"
seat_number = "B2-45"
confirmation_status = "Confirmed"

# %%
print("---------- Railway Ticket ----------")
print("Passenger Name:", passenger_name)
print("Seat Number:", seat_number)
print("Ticket Status:", confirmation_status)
print("-----------------------------------")
# Out:
# ---------- Railway Ticket ----------
# Passenger Name: Rahul Sharma
# Seat Number: B2-45
# Ticket Status: Confirmed
# -----------------------------------
