# %% [markdown]
# Store Passenger Details

# %%
passenger_name = "Rahul Sharma"
passenger_age = 28
gender = "Male"
mobile_number = 9876543210

# %%
print("Passenger Name:", passenger_name)
print("Passenger Age:", passenger_age)
print("Gender:", gender)
print("Mobile_number", mobile_number)
# Out:
# Passenger Name: Rahul Sharma
# Passenger Age: 28
# Gender: Male
# Mobile_number 9876543210

# %% [markdown]
# Store Ticket Price and Seat Number

# %%
train_name = "Rajdhani Express"
seat_number = "B2-45"
ticket_price = 2450
journey_date = "25-May-2026"

# %%
print("Train Name:", train_name)
print("Seat Number:", seat_number)
print("Ticket Price:", ticket_price)
print("Journey Date:", journey_date)
# Out:
# Train Name: Rajdhani Express
# Seat Number: B2-45
# Ticket Price: 2450
# Journey Date: 25-May-2026

# %% [markdown]
# Ticket Fare Calculations

# %%
number_of_passengers = 3
ticket_price = 2450

# %%
total_fare = number_of_passengers * ticket_price
print("Total Fare:", total_fare)
# Out:
# Total Fare: 7350

# %% [markdown]
# GST on Ticket Fare

# %%
gst_percetage = 5

# %%
gst_amount = (total_fare * gst_percetage) / 100
print("GST Amount:", gst_amount)
# Out:
# GST Amount: 367.5

# %%
final_amount = total_fare +gst_amount
print("Final Payable Amount:", final_amount)
# Out:
# Final Payable Amount: 7717.5

# %% [markdown]
# Display Complete Railway Ticket Information

# %%
print("---------- Indian Railways Ticket ----------")
print("Passenger Name:", passenger_name)
print("Train name:", train_name)
print("Seat Number:", seat_number)
print("Journey date:", journey_date)
print("paasengers:", number_of_passengers)
print("Ticket Fare:", total_fare)
print("GST Amount:", gst_amount)
print("Final Payable Amount:", final_amount)
print("--------------------------------------------")
# Out:
# ---------- Indian Railways Ticket ----------
# Passenger Name: Rahul Sharma
# Train name: Rajdhani Express
# Seat Number: B2-45
# Journey date: 25-May-2026
# paasengers: 3
# Ticket Fare: 7350
# GST Amount: 367.5
# Final Payable Amount: 7717.5
# --------------------------------------------
