# %% [markdown]
# While loop

# %%
a = int(input("Enter a Number:"))
i = 1
while i <= 10:
    print(a, "x", i, "=", a * i)
    i += 1
# Out:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %% [markdown]
# Bookings Using While Loop

# %%
total_seats = 5

while total_seats > 0:
    print("Seat Booked Successfully")
    print("Remaining seats:", total_seats -1)
    total_seats -= 1

print("All Seats Are Filled")
# Out:
# Seat Booked Successfully
# Remaining seats: 4
# Seat Booked Successfully
# Remaining seats: 3
# Seat Booked Successfully
# Remaining seats: 2
# Seat Booked Successfully
# Remaining seats: 1
# Seat Booked Successfully
# Remaining seats: 0
# All Seats Are Filled

# %% [markdown]
#  Use For Loop and Range() to Check Seat Numbers

# %%
print("Available Seat Numbers:")

for seat in range(1, 11):
    print("Seat Number:", seat)
# Out:
# Available Seat Numbers:
# Seat Number: 1
# Seat Number: 2
# Seat Number: 3
# Seat Number: 4
# Seat Number: 5
# Seat Number: 6
# Seat Number: 7
# Seat Number: 8
# Seat Number: 9
# Seat Number: 10

# %% [markdown]
# Stop Booking When Seats Become Full

# %%
total_seats = 5

for booking in range(1, 10):

    if booking > total_seats:
        print("No Seats Available")
        break

    if booking == 3:
        print("Checking Speacial Resevation")
        continue

    pass

    print("Seat", booking, "Booked Successfully")
# Out:
# Seat 1 Booked Successfully
# Seat 2 Booked Successfully
# Checking Speacial Resevation
# Seat 4 Booked Successfully
# Seat 5 Booked Successfully
# No Seats Available
