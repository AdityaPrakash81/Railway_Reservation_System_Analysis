# %% [markdown]
# Function Using Default Arguments

# %%
def reservation_status(
        passenger_name,
        ticket_status = "Confirmed"):
        print("Passenger Name: ", passenger_name)
        print("Ticket Status: ", ticket_status)

# %%
reservation_status("Rahul Sharma")
reservation_status("Amit Verma", "Waiting")
# Out:
# Passenger Name:  Rahul Sharma
# Ticket Status:  Confirmed
# Passenger Name:  Amit Verma
# Ticket Status:  Waiting

# %% [markdown]
# *args (Variable Length Arguments)

# %%
def passenger_booking(*passengers):
    print("Passenger List:")
    for name in passengers:
        print("Passenger :", name)

# %%
passenger_booking(
    "Rahul Sharma",
    "Priya Singh",
    "Amit Verma",
    "Neha Kapoor"
)
# Out:
# Passenger List:
# Passenger : Rahul Sharma
# Passenger : Priya Singh
# Passenger : Amit Verma
# Passenger : Neha Kapoor

# %% [markdown]
# **kwargs (Keyword Variable Arguments)

# %%
def ticket_details(**details):
    print("Ticket Information:")
    for key, value in details.items():
        print(key, ":", value)

# %%
ticket_details(
    passenger_name = "Rahul Sharma",
    train_name = "Rajdhani Express",
    seat_number = "B1- 21",
    fare = 2500,
    status = "Confirmed"
)
# Out:
# Ticket Information:
# passenger_name : Rahul Sharma
# train_name : Rajdhani Express
# seat_number : B1- 21
# fare : 2500
# status : Confirmed

# %% [markdown]
# Recursive Seat Countdown Function

# %%
def seat_countdown(seats):
    if seats == 0:
        print("All Seats Booked")
        return
    print("Remaining Seats: ", seats)
    seat_countdown(seats - 1)

# %%
seat_countdown(5)
# Out:
# Remaining Seats:  5
# Remaining Seats:  4
# Remaining Seats:  3
# Remaining Seats:  2
# Remaining Seats:  1
# All Seats Booked

# %% [markdown]
# Recursive Passenger Verification Function

# %%
def verify_passenger(passenger_number):
    if passenger_number == 0:
        print("Verification Completed")
        return
    print("Verifying Passenger :", passenger_number)
    verify_passenger(passenger_number - 1)

# %%
verify_passenger(3)
# Out:
# Verifying Passenger : 3
# Verifying Passenger : 2
# Verifying Passenger : 1
# Verification Completed

# %% [markdown]
# Final Advanced Booking Module

# %%
def final_booking(
        train_name = "Rajdhani Express",
        *seat_numbers
):
    print("===================================")
    print("  Railway reservation  ")
    print("===================================")
    print("Train Name: ", train_name)
    for seat in seat_numbers:
        print("Allocated Seat:", seat)

# %%
final_booking(
    "Rajdhani Express",
    "B2-21",
    "B2-22",
    "B2-23")
# Out:
# ===================================
#   Railway reservation
# ===================================
# Train Name:  Rajdhani Express
# Allocated Seat: B2-21
# Allocated Seat: B2-22
# Allocated Seat: B2-23
